# %%
import pandas as pd

data_jett = pd.read_clipboard()

# Menampilkan data
print(data_jett)
# Out:
#         NAMA GENDER  ANGKATAN  TINGGI BADAN  WAKTU PERJALANAN TEMPAT TINGGAL
# 0        JET      L      2023           175                50      TANGERANG
# 1      FELIX      L      2023           155                99         JAKBAR
# 2       DEWA      L      2023           160                88         JAKSEL
# 3       UCOK      L      2023           156                54         BEKASI
# 4      PUPUT      P      2020           167                70        TANGSEL
# 5     MIYASA      P      2021           166                20        TANGSEL
# 6    TUKIYEM      P      2019           170                54        TANGSEL
# 7     MARBOT      L      2022           169                20         BEKASI
# 8       JAKA      L      2022           189                30         BEKASI
# 9      KIWIL      L      2021           170                33      TANGERANG
# 10  MAESAROH      P      2021           158                15      TANGERANG
# ...

# %%
import pandas as pd

df = pd.read_csv("Downloads/data_jett.csv")
df
# Out:
#         NAMA GENDER  ANGKATAN  TINGGI BADAN  WAKTU PERJALANAN TEMPAT TINGGAL
# 0        JET      L      2023           175                50      TANGERANG
# 1      FELIX      L      2023           155                99         JAKBAR
# 2       DEWA      L      2023           160                88         JAKSEL
# 3       UCOK      L      2023           156                54         BEKASI
# 4      PUPUT      P      2020           167                70        TANGSEL
# 5     MIYASA      P      2021           166                20        TANGSEL
# 6    TUKIYEM      P      2019           170                54        TANGSEL
# 7     MARBOT      L      2022           169                20         BEKASI
# 8       JAKA      L      2022           189                30         BEKASI
# 9      KIWIL      L      2021           170                33      TANGERANG
# 10  MAESAROH      P      2021           158                15      TANGERANG
# ...

# %%
jett = data_jett

print(jett)
# Out:
#         NAMA GENDER  ANGKATAN  TINGGI BADAN  WAKTU PERJALANAN TEMPAT TINGGAL
# 0        JET      L      2023           175                50      TANGERANG
# 1      FELIX      L      2023           155                99         JAKBAR
# 2       DEWA      L      2023           160                88         JAKSEL
# 3       UCOK      L      2023           156                54         BEKASI
# 4      PUPUT      P      2020           167                70        TANGSEL
# 5     MIYASA      P      2021           166                20        TANGSEL
# 6    TUKIYEM      P      2019           170                54        TANGSEL
# 7     MARBOT      L      2022           169                20         BEKASI
# 8       JAKA      L      2022           189                30         BEKASI
# 9      KIWIL      L      2021           170                33      TANGERANG
# 10  MAESAROH      P      2021           158                15      TANGERANG
# ...

# %%
kolom4 = data_jett.iloc[:, 3:4]

# Menampilkan DataFrame kolom4
print(kolom4)
# Out:
#     TINGGI BADAN
# 0            175
# 1            155
# 2            160
# 3            156
# 4            167
# 5            166
# 6            170
# 7            169
# 8            189
# 9            170
# 10           158
# 11           160
# 12           172
# 13           160
# 14           178
# 15           176
# 16           180
# 17           161
# 18           190
# 19           166
# 20           170
# 21           160
# 22           164
# 23           174
# 24           170
# 25           168
# 26           160
# 27           170
# 28           170
# 29           177

# %%
jett['TINGGI BADAN'] = pd.to_numeric(jett['TINGGI BADAN'])

import numpy as np

jett['TINGGI BADAN'] = jett['TINGGI BADAN'].apply(lambda x: 'tinggi' if x > 160 else 'pendek')

# Menampilkan DataFrame setelah modifikasi
print(jett)
# Out:
#         NAMA GENDER  ANGKATAN TINGGI BADAN  WAKTU PERJALANAN TEMPAT TINGGAL
# 0        JET      L      2023       tinggi                50      TANGERANG
# 1      FELIX      L      2023       pendek                99         JAKBAR
# 2       DEWA      L      2023       pendek                88         JAKSEL
# 3       UCOK      L      2023       pendek                54         BEKASI
# 4      PUPUT      P      2020       tinggi                70        TANGSEL
# 5     MIYASA      P      2021       tinggi                20        TANGSEL
# 6    TUKIYEM      P      2019       tinggi                54        TANGSEL
# 7     MARBOT      L      2022       tinggi                20         BEKASI
# 8       JAKA      L      2022       tinggi                30         BEKASI
# 9      KIWIL      L      2021       tinggi                33      TANGERANG
# 10  MAESAROH      P      2021       pendek                15      TANGERANG
# ...

# %%
jett = data_jett

jett = pd.DataFrame(jett)

# Menambahkan kolom baru 'Jurusan' dengan nilai 'Infor20'
jett['Jurusan'] = 'Infor20'

# Menambahkan kolom baru 'Fakultas' dengan nilai 'FTI'
jett['Fakultas'] = 'FTI'

print(jett)
# Out:
#         NAMA GENDER  ANGKATAN TINGGI BADAN  WAKTU PERJALANAN TEMPAT TINGGAL  \
# 0        JET      L      2023       tinggi                50      TANGERANG
# 1      FELIX      L      2023       pendek                99         JAKBAR
# 2       DEWA      L      2023       pendek                88         JAKSEL
# 3       UCOK      L      2023       pendek                54         BEKASI
# 4      PUPUT      P      2020       tinggi                70        TANGSEL
# 5     MIYASA      P      2021       tinggi                20        TANGSEL
# 6    TUKIYEM      P      2019       tinggi                54        TANGSEL
# 7     MARBOT      L      2022       tinggi                20         BEKASI
# 8       JAKA      L      2022       tinggi                30         BEKASI
# 9      KIWIL      L      2021       tinggi                33      TANGERANG
# 10  MAESAROH      P      2021       pendek                15      TANGERANG
# ...

# %%
jett = jett.drop(columns=['Fakultas'])

# Menampilkan DataFrame 'jett' 
print(jett)
# Out:
#         NAMA GENDER  ANGKATAN TINGGI BADAN  WAKTU PERJALANAN TEMPAT TINGGAL  \
# 0        JET      L      2023       tinggi                50      TANGERANG
# 1      FELIX      L      2023       pendek                99         JAKBAR
# 2       DEWA      L      2023       pendek                88         JAKSEL
# 3       UCOK      L      2023       pendek                54         BEKASI
# 4      PUPUT      P      2020       tinggi                70        TANGSEL
# 5     MIYASA      P      2021       tinggi                20        TANGSEL
# 6    TUKIYEM      P      2019       tinggi                54        TANGSEL
# 7     MARBOT      L      2022       tinggi                20         BEKASI
# 8       JAKA      L      2022       tinggi                30         BEKASI
# 9      KIWIL      L      2021       tinggi                33      TANGERANG
# 10  MAESAROH      P      2021       pendek                15      TANGERANG
# ...

# %%
kolom1dan2 = data_jett.iloc[:, 0:2]
kolom3dan4 = data_jett.iloc[:, 2:4]

# Menampilkan DataFrame kolom1dan2
print(kolom1dan2)

print(kolom3dan4)
# Out:
#         NAMA GENDER
# 0        JET      L
# 1      FELIX      L
# 2       DEWA      L
# 3       UCOK      L
# 4      PUPUT      P
# 5     MIYASA      P
# 6    TUKIYEM      P
# 7     MARBOT      L
# 8       JAKA      L
# 9      KIWIL      L
# 10  MAESAROH      P
# 11      SARI      P
# 12     PURBA      L
# 13      JEKI      L
# 14      IWAN      L
# 15      HERI      L
# 16     JAWAN      L
# 17       SRI      P
# 18     DOENG      L
# 19     MKIYA      P
# 20      IMAM      L
# 21      SILA      P
# 22     SINTA      P
# 23     UJANG      L
# 24     DEMAS      L
# 25     FADIL      L
# 26      DAPA      L
# 27     RIFQI      L
# 28    ANDREW      L
# 29     QUSOY      L
#     ANGKATAN TINGGI BADAN
# 0       2023       tinggi
# 1       2023       pendek
# 2       2023       pendek
# 3       2023       pendek
# 4       2020       tinggi
# 5       2021       tinggi
# 6       2019       tinggi
# 7       2022       tinggi
# 8       2022       tinggi
# 9       2021       tinggi
# ...

# %%
# Menggabungkan dua DataFrame 
kolom1sd4 = pd.concat([kolom1dan2, kolom3dan4], axis=1)

# Menampilkan DataFrame kolom1sd4
print(kolom1sd4)
# Out:
#         NAMA GENDER  ANGKATAN TINGGI BADAN
# 0        JET      L      2023       tinggi
# 1      FELIX      L      2023       pendek
# 2       DEWA      L      2023       pendek
# 3       UCOK      L      2023       pendek
# 4      PUPUT      P      2020       tinggi
# 5     MIYASA      P      2021       tinggi
# 6    TUKIYEM      P      2019       tinggi
# 7     MARBOT      L      2022       tinggi
# 8       JAKA      L      2022       tinggi
# 9      KIWIL      L      2021       tinggi
# 10  MAESAROH      P      2021       pendek
# 11      SARI      P      2020       pendek
# 12     PURBA      L      2023       tinggi
# 13      JEKI      L      2021       pendek
# 14      IWAN      L      2023       tinggi
# 15      HERI      L      2023       tinggi
# 16     JAWAN      L      2019       tinggi
# 17       SRI      P      2018       tinggi
# 18     DOENG      L      2020       tinggi
# 19     MKIYA      P      2018       tinggi
# 20      IMAM      L      2020       tinggi
# ...

# %%
# Menggabungkan baris dari dua DataFrame
baris1sd5 = data_jett.iloc[0:5, :]
baris25sd30 = data_jett.iloc[24:30, :]
baris1sd30 = pd.concat([baris1sd5, baris25sd30])

# Menampilkan DataFrame baris1sd30
print(baris1sd30)
# Out:
#       NAMA GENDER  ANGKATAN TINGGI BADAN  WAKTU PERJALANAN TEMPAT TINGGAL  \
# 0      JET      L      2023       tinggi                50      TANGERANG
# 1    FELIX      L      2023       pendek                99         JAKBAR
# 2     DEWA      L      2023       pendek                88         JAKSEL
# 3     UCOK      L      2023       pendek                54         BEKASI
# 4    PUPUT      P      2020       tinggi                70        TANGSEL
# 24   DEMAS      L      2023       tinggi                60         JAKBAR
# 25   FADIL      L      2023       tinggi                50      TANGERANG
# 26    DAPA      L      2023       pendek                39         JAKBAR
# 27   RIFQI      L      2023       tinggi                50         JAKSEL
# 28  ANDREW      L      2023       tinggi                40         JAKBAR
# 29   QUSOY      L      2023       tinggi                66         BEKASI
#
#     Jurusan Fakultas
# 0   Infor20      FTI
# 1   Infor20      FTI
# ...

# %%
data_jett_sort = data_jett.sort_values(by='WAKTU PERJALANAN')

print(data_jett_sort)
# Out:
#         NAMA GENDER  ANGKATAN TINGGI BADAN  WAKTU PERJALANAN TEMPAT TINGGAL  \
# 10  MAESAROH      P      2021       pendek                15      TANGERANG
# 7     MARBOT      L      2022       tinggi                20         BEKASI
# 5     MIYASA      P      2021       tinggi                20        TANGSEL
# 18     DOENG      L      2020       tinggi                22         JAKBAR
# 21      SILA      P      2020       pendek                25         JAKBAR
# 8       JAKA      L      2022       tinggi                30         BEKASI
# 17       SRI      P      2018       tinggi                30         BEKASI
# 9      KIWIL      L      2021       tinggi                33      TANGERANG
# 26      DAPA      L      2023       pendek                39         JAKBAR
# 23     UJANG      L      2021       tinggi                40        TANGSEL
# 28    ANDREW      L      2023       tinggi                40         JAKBAR
# ...
